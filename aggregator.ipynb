# %%
import datetime as dt
import json
import redis
import pandas as pd
import pprint

red = redis.StrictRedis()

id_dict_map = {'238312155374' : 'nissanusa' ,
               '90671958533' : 'lexus' ,
               '197052454200' : 'toyota'
#               'ford': '22166130048',
#               'FordCars' : '55712353286',
#               'chevrolet': '77589292295',
#               'MazdaUSA': '337363685362',
#               'cadillac': '95690769922',
#               'Infiniti': '58128939954',
#               'NissanElectric': '141137487795'
              }

data_breakdown_dict = {
                    'nissanusa': {'2017Q1': {'Posts' : 0, 'likes' : 0, 'angries' : 0, 'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                '2017Q2': {'Posts' : 0, 'likes' : 0, 'angries' : 0, 'sadnesses':0, 'wows':0, 'love':0, 'hahas':0,'Comments' : 0 },
                                '2017Q3': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                '2017Q4': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                 '2018Q1': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                 '2018Q2': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0}
                             },
                   'lexus': {'2017Q1': {'Posts' : 0, 'likes' : 0, 'angries' : 0, 'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0 },
                                '2017Q2': {'Posts' : 0, 'likes' : 0, 'angries' : 0, 'sadnesses':0, 'wows':0, 'love':0, 'hahas':0,'Comments' : 0 },
                                '2017Q3': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                '2017Q4': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                 '2018Q1': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                 '2018Q2': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0}
                             },
                   'toyota': {'2017Q1': {'Posts' : 0, 'likes' : 0, 'angries' : 0, 'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0 },
                                '2017Q2': {'Posts' : 0, 'likes' : 0, 'angries' : 0, 'sadnesses':0, 'wows':0, 'love':0, 'hahas':0,'Comments' : 0 },
                                '2017Q3': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                '2017Q4': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                 '2018Q1': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0},
                                 '2018Q2': {'Posts' : 0, 'likes' : 0, 'angries' : 0,'sadnesses':0, 'wows':0, 'love':0, 'hahas':0, 'Comments' : 0}
                             }
                  }

reply = json.loads(red.execute_command('JSON.GET', 1))
with open('data7.txt', 'w') as outfile:  
    json.dump(reply, outfile, indent=4)
replies = []
def aggregate(reply):
#     print(reply)
    if isinstance(reply, dict):
        for k, v in reply.items():

    #         if isinstance(rep, dict):
#             print(k, v)
            if isinstance(v, dict) and 'id' in v:
                print(k, v)
                if reply not in replies:
#                     print(k, v)
                    date_split = v['created_time'].split("-")
                    # print(pd.Timestamp(dt.date(int(date_split[0]), int(date_split[1]), int(date_split[2].split("T")[0]))).quarter)
                    quarter = date_split[0]+'Q'+str(pd.Timestamp(dt.date(int(date_split[0]), int(date_split[1]), int(date_split[2].split("T")[0]))).quarter)



                    if 'shares' in v:
                        
        #                 print(id_dict_map[v['id'].split("_")[0]])
                        data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['Posts'] += 1
                        data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['likes'] += v['likes']
                        data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['angries'] += v['angries']
                        data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['sadnesses'] += v['sadnesses']
                        data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['wows'] += v['wows']
                        data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['love'] += v['loves']
                        data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['hahas'] += v['hahas']
        #                 data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['shares'] += v['shares']
                    else:
                        pprint.pprint(v)
                        if v['id'].split("_")[0] in id_dict_map:
                            data_breakdown_dict[id_dict_map[v['id'].split("_")[0]]][quarter]['Comments'] += 1
                    #             print(data_breakdown_dict[id_dict_map[reply['id'].split("_")[0]]])
                replies.append(reply)
            else:
                aggregate(v)

aggregate(reply)

print(data_breakdown_dict)
# Out:
# 238312155374_10160632821080375 {'id': '238312155374_10160632821080375', 'comment': 'Two EVs are better than one. #NissanLEAF #SimplyAmazing', 'created_time': '2018-06-28T14:00:01+0000', 'likes': 11, 'angries': 0, 'sadnesses': 0, 'hahas': 0, 'wows': 0, 'loves': 2, 'shares': 8, 'comments': 2, '10160632821080375_10160633145725375': {'id': '10160632821080375_10160633145725375', 'comment': "Don't buy a sorry Nissan. These folks will screw you over. So if you buy one don't forget you was Warned", 'created_time': '2018-06-28T15:43:35+0000', 'likes': 0, 'angries': 0, 'sadnesses': 0, 'hahas': 0, 'wows': 0, 'loves': 0, '10160632821080375_10160633201765375': {'id': '10160632821080375_10160633201765375', 'comment': 'I second that! Buy anything but a Nissan!', 'created_time': '2018-06-28T16:04:56+0000', 'likes': 0, 'angries': 0, 'sadnesses': 0, 'hahas': 0, 'wows': 0, 'loves': 0}}}
# ...
